# %% [markdown]
# ## Votes

# %%
import sqlite3
import os
import numpy as np
from numpy import array, mean
from numpy import diag, savetxt
from numpy import zeros, append
from scipy.linalg import svd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import preprocessing
import pandas as pd

# %% [markdown]
# ## Convert DB query result to matrix

# %%
db = sqlite3.connect('predikon.db')
def query_db(query, args=(), one=False):
    cur = db.execute(query, args)
    rv = cur.fetchall()
    return (rv[0] if rv else None) if one else rv


res = query_db('SELECT municipality.id as mcp_id, vote.id as vote_id, ROUND(result.num_yes * 100.0 / result.num_total, 1)/100 AS percentage, municipality.ogd_id  FROM result, municipality, vote where result.municipality_id == municipality.id AND vote.id == result.vote_id ')
rows = np.zeros(len(res)).astype(np.int64)
cols = np.zeros(len(res)).astype(np.int64)
vals = np.zeros(len(res))
ids = np.zeros((2222,1)).astype(np.int64)
voteMatrix = np.zeros((2222,328))
for vote in res:
    voteMatrix[vote[0]-1,vote[1]-1] = vote[2]
    ids[vote[0]-1] = vote[3]
print((voteMatrix[0][0]))
print(ids[2221])
# Out:
# 0.635
# [261]

# %% [markdown]
# ## PCA

# %%
#voteMatrix = preprocessing.StandardScaler().fit_transform(voteMatrix)
#row_means = np.mean(voteMatrix, axis=1)
#print(len(mean(voteMatrix, 0)))
voteMatrix -= mean(voteMatrix, 0)
#voteMatrix = preprocessing.normalize(voteMatrix)
pca = PCA(n_components=2, svd_solver='full')
pca.fit(voteMatrix)
#print(pca.components_)
u,s,v = np.linalg.svd(voteMatrix.T)

# %%
def draw_vector(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=2,
                    shrinkA=0, shrinkB=0)
# plot data
plt.scatter(voteMatrix[:, 0], voteMatrix[:, 1], alpha=0.2)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v)
plt.axis('equal')
# Out:
# (-0.6066095561169021,
#  0.5131037055318433,
#  -0.6253755203334902,
#  0.5049776805495119)

# %% [markdown]
# ## DR

# %%
pca = PCA(n_components=2)
pca.fit(voteMatrix)
X_pca = pca.transform(voteMatrix)
X_new = pca.inverse_transform(X_pca)
#plt.scatter(voteMatrix[:, 0], voteMatrix[:, 1], alpha=0.2)
plt.scatter(X_pca[:, 1], X_pca[:, 0],s=0.5, alpha=0.8)
plt.axis('equal');
print(np.append(X_pca,ids, axis=1))

savetxt("voteMatrix.csv",np.append(X_pca,ids, axis=1),fmt='%.10f', delimiter=",")
savetxt("ids.csv",ids,fmt='%.1d', delimiter=",")
# Out:
# [[-1.14334218e-01 -1.29156037e+00  1.00000000e+00]
#  [ 1.18192068e-01 -1.00633093e+00  2.00000000e+00]
#  [-1.70201893e-01 -1.52161814e+00  3.00000000e+00]
#  ...
#  [-3.14060289e-01  1.37373876e+00  8.68000000e+02]
#  [-7.86541699e-02  1.57803411e+00  2.30000000e+02]
#  [-2.75732326e-01  1.44237357e+00  2.61000000e+02]]

# %% [markdown]
# ## Add fake partial data
#
# Useful for testing prediction.

# %%
df = pd.read_csv('voteMatrix.csv', delimiter='\t')
# this line creates a new column, which is a Pandas series.
# we then add the series to the dataframe, which holds our parsed CSV file
df['NewColumn'] = pd.Series(ids[:,0])
# save the dataframe to CSV
df.to_csv('new2.csv', sep='\t')

# %% [markdown]
# ## Add partial data for "Initiative mitage"

# %%
for file in list(reversed(glob.glob('../json/20190210*.json'))):
    with open(file) as f:
        data = json.load(f)
        results = get_results(data)
        save_results(results)
    print(f'Inserted {file}')
